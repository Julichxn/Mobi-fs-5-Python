# %% [markdown]
# # [Lab Session 2](otsu.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **[Task 2.1.]()** Implement Otsu thresholding as a re-usable function:

# %%
imgf = plt.imread('data/NIH3T3/im/dna-0.png')
otsu1 = []

def otsu_thresholding(imgf):
    img8 = (imgf * 255).round().astype(np.uint8)
    h = np.bincount(img8.flatten(), minlength =256)
    
    for T in range(0,256):
        tot_num1 = np.sum(h[0:T])
        tot_num2 = np.sum(h[T:256])
        if tot_num1== 0 or tot_num2 == 0:
          otsu1.append(np.inf)
          continue
        mean_int1 = (1/tot_num1)* np.sum(h[0:T]*np.arange(0,T))
        #print(mean_int)
        int_var1 = (1/tot_num1)* np.sum(((np.arange(0,T))- mean_int1)**2 * h[0:T])
    
        mean_int2 = (1/tot_num2)* np.sum(h[T:256]*np.arange(T,256))
        #print(mean_int)
        int_var2 = (1/tot_num2)* np.sum(((np.arange(T,256))-mean_int2)**2 * h[T:256])
        otsu = (tot_num1 *  int_var1 + tot_num2*int_var2)
        otsu1.append(otsu)
        T_otsu = (otsu1.index(min(otsu1)))
        seg = (img8 >= T_otsu).astype(bool)
        #print(otsu1)
    return seg

# %% [markdown]
# **[Task 2.2.]()** Implement a re-usable function to compute the Dice coefficient:

# %%
def compute_dice(bin1, bin2):
    assert bin1.dtype == bool
    assert bin2.dtype == bool
    Zähler = np.sum(bin1 *bin2)
    Nenner1 = np.sum(bin1)
    Nenner2 = np.sum(bin2)

    Dice_score = 2*Zähler / (Nenner1 +Nenner2)
    #print(Dice_score)
    
    return Dice_score

# %% [markdown]
# **[Task 2.3.]()** Test your implementations from above:

# %%
imgf = plt.imread('data/NIH3T3/im/dna-0.png')
G = plt.imread('data/NIH3T3/gt/0.png').astype(bool)

Seg = otsu_thresholding(imgf)
Dice = compute_dice(G, Seg)

print(Seg)
print(Dice)
# Out:
# [[ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# 0.8943783223933183

# %% [markdown]
# The result should be the same as in your [otsu.ipynb](otsu.ipynb) notebook.

# %% [markdown]
# **[Task 2.4.]()** Perform batch processing:

# %%
#images = plt.imread(f'data/NIH3T3/im/dna-{i}.png')
#ground_truth_images = plt.imread(f'data/NIH3T3/gt/{i}.png')

#Seg1 = otsu_thresholding(imges)
#Dice1 = compute_dice(ground_truth_images , Seg1)

dice_list = []

for i in (28, 29, 33, 44, 46, 49):
   images = plt.imread(f'data/NIH3T3/im/dna-{i}.png')
   ground_truth_images = plt.imread(f'data/NIH3T3/gt/{i}.png').astype(bool)
   Seg1 = otsu_thresholding(images)
   Dice1 = compute_dice(ground_truth_images,Seg1)
   #print(Seg1)
   print(Dice1)
   dice_list.append(Dice1)
   
print(np.mean(dice_list))
# Out:
# 0.7993590316749856
# 0.627125408639006
# 0.35338755033034924
# 0.5221077499702446
# 0.3369249652864667
# 0.46647412918405173
# 0.5175631391808506
